# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random 
from config import weather_api_key
from citipy import citipy
import requests
from datetime import datetime
from scipy.stats import linregress
from config import g_key

# %%
# creat set of random latitude and longitude
lat=np.random.uniform(low=-90,high=90,size=2000)
lngs=np.random.uniform(low=-180,high=180,size=2000)
lat_lngs=zip(lat,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()     
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current_Description":weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kamenka
# Processing Record 2 of Set 1 | tilichiki
# Processing Record 3 of Set 1 | ijui
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | yatou
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | yushan
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | camapua
# Processing Record 12 of Set 1 | maple creek
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | hagere hiywet
# Processing Record 15 of Set 1 | codrington
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | half moon bay
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | miram shah
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | lorengau
# Processing Record 22 of Set 1 | bongaree
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | marawi
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | praya
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 1 | torbay
# Processing Record 32 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 1 | bumbuna
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | san rafael
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | egvekinot
# Processing Record 43 of Set 1 | progreso
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | marzuq
# Processing Record 46 of Set 1 | gimbi
# Processing Record 47 of Set 1 | turgoyak
# Processing Record 48 of Set 1 | manta
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | nouadhibou
# Processing Record 1 of Set 2 | meulaboh
# Processing Record 2 of Set 2 | toktogul
# Processing Record 3 of Set 2 | tokur
# Processing Record 4 of Set 2 | mazatlan
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | nome
# Processing Record 8 of Set 2 | standerton
# Processing Record 9 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 2 | rio de janeiro
# Processing Record 11 of Set 2 | valle hermoso
# Processing Record 12 of Set 2 | itarema
# Processing Record 13 of Set 2 | ambulu
# Processing Record 14 of Set 2 | hambantota
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | faanui
# Processing Record 17 of Set 2 | aasiaat
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | skotina
# Processing Record 22 of Set 2 | carauari
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | atar
# Processing Record 26 of Set 2 | balaipungut
# Processing Record 27 of Set 2 | pundaguitan
# Processing Record 28 of Set 2 | port lincoln
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | farafangana
# Processing Record 31 of Set 2 | kalmunai
# Processing Record 32 of Set 2 | mago
# Processing Record 33 of Set 2 | santo tomas
# Processing Record 34 of Set 2 | mercedes
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | te anau
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | ngunguru
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | valdemarpils
# Processing Record 42 of Set 2 | asau
# Processing Record 43 of Set 2 | alta floresta
# Processing Record 44 of Set 2 | aalburg
# Processing Record 45 of Set 2 | hit
# Processing Record 46 of Set 2 | goundam
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | shingu
# Processing Record 50 of Set 2 | waipawa
# Processing Record 1 of Set 3 | teya
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | komsomolskiy
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 3 | ahipara
# Processing Record 8 of Set 3 | coxim
# Processing Record 9 of Set 3 | rocha
# Processing Record 10 of Set 3 | taoudenni
# Processing Record 11 of Set 3 | mandalgovi
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | portland
# Processing Record 14 of Set 3 | velke karlovice
# Processing Record 15 of Set 3 | seymour
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | xining
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | sinnamary
# Processing Record 20 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | canutama
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | nioro
# Processing Record 26 of Set 3 | addi ugri
# City not found. Skipping...
# Processing Record 27 of Set 3 | yaan
# Processing Record 28 of Set 3 | broome
# Processing Record 29 of Set 3 | ostersund
# Processing Record 30 of Set 3 | umm lajj
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | northam
# Processing Record 34 of Set 3 | vuktyl
# Processing Record 35 of Set 3 | charlottetown
# Processing Record 36 of Set 3 | luderitz
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | quatre cocos
# Processing Record 41 of Set 3 | anloga
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | porto de moz
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | bluff
# Processing Record 46 of Set 3 | namatanai
# Processing Record 47 of Set 3 | peru
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | miraflores
# Processing Record 50 of Set 3 | poum
# Processing Record 1 of Set 4 | sroda wielkopolska
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | liepaja
# Processing Record 5 of Set 4 | souillac
# Processing Record 6 of Set 4 | mareeba
# Processing Record 7 of Set 4 | makakilo city
# Processing Record 8 of Set 4 | peniche
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | imamoglu
# Processing Record 11 of Set 4 | dukat
# Processing Record 12 of Set 4 | surgut
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | srednekolymsk
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | yerbogachen
# Processing Record 17 of Set 4 | akyab
# Processing Record 18 of Set 4 | prainha
# Processing Record 19 of Set 4 | emba
# Processing Record 20 of Set 4 | umm kaddadah
# Processing Record 21 of Set 4 | matagami
# Processing Record 22 of Set 4 | palembang
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | okhotsk
# Processing Record 25 of Set 4 | jemnice
# Processing Record 26 of Set 4 | menongue
# Processing Record 27 of Set 4 | corn island
# Processing Record 28 of Set 4 | esmeraldas
# Processing Record 29 of Set 4 | surt
# Processing Record 30 of Set 4 | qostanay
# Processing Record 31 of Set 4 | thinadhoo
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | mirnyy
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | coquimbo
# Processing Record 36 of Set 4 | bundaberg
# Processing Record 37 of Set 4 | khandbari
# Processing Record 38 of Set 4 | luanda
# Processing Record 39 of Set 4 | manokwari
# Processing Record 40 of Set 4 | bodden town
# Processing Record 41 of Set 4 | greenock
# Processing Record 42 of Set 4 | constitucion
# Processing Record 43 of Set 4 | savinka
# Processing Record 44 of Set 4 | batken
# Processing Record 45 of Set 4 | maicao
# Processing Record 46 of Set 4 | shache
# Processing Record 47 of Set 4 | lobito
# Processing Record 48 of Set 4 | astorga
# Processing Record 49 of Set 4 | patiya
# Processing Record 50 of Set 4 | nantucket
# Processing Record 1 of Set 5 | cidreira
# Processing Record 2 of Set 5 | henties bay
# Processing Record 3 of Set 5 | adeje
# Processing Record 4 of Set 5 | morgan city
# Processing Record 5 of Set 5 | homer
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | carmen
# Processing Record 8 of Set 5 | mali
# Processing Record 9 of Set 5 | ambilobe
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 12 of Set 5 | brae
# Processing Record 13 of Set 5 | sorland
# Processing Record 14 of Set 5 | ossora
# Processing Record 15 of Set 5 | tukrah
# Processing Record 16 of Set 5 | storforshei
# Processing Record 17 of Set 5 | richards bay
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | merke
# Processing Record 20 of Set 5 | tiznit
# Processing Record 21 of Set 5 | along
# Processing Record 22 of Set 5 | potosi
# Processing Record 23 of Set 5 | almoradi
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | samarai
# Processing Record 27 of Set 5 | sisimiut
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | kishi
# Processing Record 30 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 5 | dovolnoye
# Processing Record 32 of Set 5 | iqaluit
# Processing Record 33 of Set 5 | salalah
# Processing Record 34 of Set 5 | yorosso
# Processing Record 35 of Set 5 | turukhansk
# Processing Record 36 of Set 5 | sumbe
# Processing Record 37 of Set 5 | tabou
# Processing Record 38 of Set 5 | doha
# Processing Record 39 of Set 5 | davlekanovo
# Processing Record 40 of Set 5 | tocopilla
# Processing Record 41 of Set 5 | young
# Processing Record 42 of Set 5 | hornepayne
# Processing Record 43 of Set 5 | borogontsy
# Processing Record 44 of Set 5 | bahia blanca
# Processing Record 45 of Set 5 | alice springs
# Processing Record 46 of Set 5 | puerto escondido
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | zeulenroda
# Processing Record 49 of Set 5 | meadow lake
# Processing Record 50 of Set 5 | creel
# Processing Record 1 of Set 6 | nanganga
# Processing Record 2 of Set 6 | san borja
# Processing Record 3 of Set 6 | kirakira
# Processing Record 4 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 6 | mehamn
# Processing Record 6 of Set 6 | mahon
# Processing Record 7 of Set 6 | sucua
# Processing Record 8 of Set 6 | hernani
# Processing Record 9 of Set 6 | bar harbor
# Processing Record 10 of Set 6 | tombouctou
# Processing Record 11 of Set 6 | kurilsk
# Processing Record 12 of Set 6 | puerto ayora
# Processing Record 13 of Set 6 | broken hill
# Processing Record 14 of Set 6 | priyutnoye
# Processing Record 15 of Set 6 | tirumullaivasal
# Processing Record 16 of Set 6 | mushie
# Processing Record 17 of Set 6 | seoul
# Processing Record 18 of Set 6 | imbituba
# Processing Record 19 of Set 6 | mulanje
# Processing Record 20 of Set 6 | kyabe
# Processing Record 21 of Set 6 | pevek
# Processing Record 22 of Set 6 | balykshi
# Processing Record 23 of Set 6 | yar-sale
# Processing Record 24 of Set 6 | nanortalik
# Processing Record 25 of Set 6 | husavik
# Processing Record 26 of Set 6 | cherskiy
# Processing Record 27 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | mogadishu
# Processing Record 31 of Set 6 | warri
# Processing Record 32 of Set 6 | batamshinskiy
# Processing Record 33 of Set 6 | namibe
# Processing Record 34 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 6 | nyurba
# Processing Record 36 of Set 6 | teguldet
# Processing Record 37 of Set 6 | etchojoa
# Processing Record 38 of Set 6 | huarmey
# Processing Record 39 of Set 6 | caracoli
# Processing Record 40 of Set 6 | serenje
# Processing Record 41 of Set 6 | labuhan
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | paralimni
# Processing Record 44 of Set 6 | kigoma
# Processing Record 45 of Set 6 | saurimo
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 6 | villaviciosa
# Processing Record 49 of Set 6 | wells
# Processing Record 50 of Set 6 | apollonia
# Processing Record 1 of Set 7 | corrente
# Processing Record 2 of Set 7 | sao filipe
# Processing Record 3 of Set 7 | hobyo
# Processing Record 4 of Set 7 | mayo
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | kushiro
# Processing Record 7 of Set 7 | high level
# Processing Record 8 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 7 | port-gentil
# Processing Record 10 of Set 7 | necochea
# Processing Record 11 of Set 7 | chandbali
# Processing Record 12 of Set 7 | moorhead
# Processing Record 13 of Set 7 | harper
# Processing Record 14 of Set 7 | airai
# Processing Record 15 of Set 7 | abha
# Processing Record 16 of Set 7 | jiayuguan
# Processing Record 17 of Set 7 | paka
# Processing Record 18 of Set 7 | killarney
# Processing Record 19 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 7 | verkhovyna
# Processing Record 21 of Set 7 | nandyal
# Processing Record 22 of Set 7 | dieppe
# Processing Record 23 of Set 7 | macae
# Processing Record 24 of Set 7 | hofn
# Processing Record 25 of Set 7 | provideniya
# Processing Record 26 of Set 7 | saint-joseph
# Processing Record 27 of Set 7 | huinan
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | dunedin
# Processing Record 30 of Set 7 | ponta do sol
# Processing Record 31 of Set 7 | aswan
# Processing Record 32 of Set 7 | le port
# Processing Record 33 of Set 7 | yermakovskoye
# Processing Record 34 of Set 7 | udarnyy
# Processing Record 35 of Set 7 | vanimo
# Processing Record 36 of Set 7 | batemans bay
# Processing Record 37 of Set 7 | salihorsk
# Processing Record 38 of Set 7 | heze
# Processing Record 39 of Set 7 | thaba-tseka
# Processing Record 40 of Set 7 | yenagoa
# Processing Record 41 of Set 7 | margate
# Processing Record 42 of Set 7 | ulaangom
# Processing Record 43 of Set 7 | buala
# Processing Record 44 of Set 7 | port blair
# Processing Record 45 of Set 7 | ilulissat
# Processing Record 46 of Set 7 | diffa
# Processing Record 47 of Set 7 | lagoa
# Processing Record 48 of Set 7 | kasongo
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 50 of Set 7 | moncada
# Processing Record 1 of Set 8 | saint-augustin
# Processing Record 2 of Set 8 | port macquarie
# Processing Record 3 of Set 8 | rudbar
# Processing Record 4 of Set 8 | gioia tauro
# Processing Record 5 of Set 8 | soligalich
# Processing Record 6 of Set 8 | lopsmarka
# Processing Record 7 of Set 8 | the valley
# Processing Record 8 of Set 8 | kusti
# Processing Record 9 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 8 | cooma
# Processing Record 11 of Set 8 | xaxim
# Processing Record 12 of Set 8 | bolobo
# Processing Record 13 of Set 8 | venado tuerto
# Processing Record 14 of Set 8 | zonguldak
# Processing Record 15 of Set 8 | puerto colombia
# Processing Record 16 of Set 8 | nikolskoye
# Processing Record 17 of Set 8 | bintulu
# Processing Record 18 of Set 8 | grindavik
# Processing Record 19 of Set 8 | virar
# Processing Record 20 of Set 8 | fairbanks
# Processing Record 21 of Set 8 | atocha
# Processing Record 22 of Set 8 | dwarka
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | halifax
# Processing Record 25 of Set 8 | pantai remis
# Processing Record 26 of Set 8 | inuvik
# Processing Record 27 of Set 8 | coos bay
# Processing Record 28 of Set 8 | kavaratti
# Processing Record 29 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 8 | caravelas
# Processing Record 31 of Set 8 | dalinghe
# City not found. Skipping...
# Processing Record 32 of Set 8 | pangnirtung
# Processing Record 33 of Set 8 | leningradskiy
# Processing Record 34 of Set 8 | san juan
# Processing Record 35 of Set 8 | vicuna
# Processing Record 36 of Set 8 | zhigansk
# Processing Record 37 of Set 8 | buraydah
# Processing Record 38 of Set 8 | santa cruz
# Processing Record 39 of Set 8 | tamandare
# Processing Record 40 of Set 8 | flinders
# Processing Record 41 of Set 8 | lompoc
# Processing Record 42 of Set 8 | ouesso
# Processing Record 43 of Set 8 | amahai
# Processing Record 44 of Set 8 | tuatapere
# Processing Record 45 of Set 8 | aligudarz
# Processing Record 46 of Set 8 | touros
# Processing Record 47 of Set 8 | port hedland
# Processing Record 48 of Set 8 | pitimbu
# Processing Record 49 of Set 8 | guozhen
# Processing Record 50 of Set 8 | merauke
# Processing Record 1 of Set 9 | kloulklubed
# Processing Record 2 of Set 9 | uspenka
# Processing Record 3 of Set 9 | goycay
# City not found. Skipping...
# Processing Record 4 of Set 9 | teruel
# Processing Record 5 of Set 9 | tonj
# Processing Record 6 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 9 | oranjemund
# Processing Record 8 of Set 9 | kristinehamn
# Processing Record 9 of Set 9 | troy
# Processing Record 10 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 12 of Set 9 | zamania
# Processing Record 13 of Set 9 | quirinopolis
# Processing Record 14 of Set 9 | tikapur
# Processing Record 15 of Set 9 | bandarbeyla
# Processing Record 16 of Set 9 | le pont-de-claix
# Processing Record 17 of Set 9 | the pas
# Processing Record 18 of Set 9 | duki
# Processing Record 19 of Set 9 | hovd
# Processing Record 20 of Set 9 | dhidhdhoo
# Processing Record 21 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 9 | raudeberg
# Processing Record 23 of Set 9 | murray bridge
# Processing Record 24 of Set 9 | kutum
# Processing Record 25 of Set 9 | kollam
# Processing Record 26 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 9 | sao joao da barra
# Processing Record 28 of Set 9 | bengkulu
# Processing Record 29 of Set 9 | pisco
# Processing Record 30 of Set 9 | san quintin
# Processing Record 31 of Set 9 | wanganui
# Processing Record 32 of Set 9 | zandvoort
# Processing Record 33 of Set 9 | bilibino
# Processing Record 34 of Set 9 | hami
# Processing Record 35 of Set 9 | vaitape
# Processing Record 36 of Set 9 | iberia
# Processing Record 37 of Set 9 | beinamar
# Processing Record 38 of Set 9 | bonavista
# Processing Record 39 of Set 9 | ilhabela
# Processing Record 40 of Set 9 | tala
# Processing Record 41 of Set 9 | brunico
# Processing Record 42 of Set 9 | thompson
# Processing Record 43 of Set 9 | madimba
# Processing Record 44 of Set 9 | beringovskiy
# Processing Record 45 of Set 9 | beruwala
# Processing Record 46 of Set 9 | boden
# Processing Record 47 of Set 9 | sapai
# City not found. Skipping...
# Processing Record 48 of Set 9 | conceicao do araguaia
# Processing Record 49 of Set 9 | bethel
# Processing Record 50 of Set 9 | naze
# Processing Record 1 of Set 10 | xianyang
# Processing Record 2 of Set 10 | sept-iles
# Processing Record 3 of Set 10 | vila franca do campo
# Processing Record 4 of Set 10 | bose
# Processing Record 5 of Set 10 | caluquembe
# Processing Record 6 of Set 10 | makung
# City not found. Skipping...
# Processing Record 7 of Set 10 | wad madani
# Processing Record 8 of Set 10 | moyobamba
# Processing Record 9 of Set 10 | eldorado
# Processing Record 10 of Set 10 | shakawe
# Processing Record 11 of Set 10 | wajima
# Processing Record 12 of Set 10 | ixtapa
# Processing Record 13 of Set 10 | mahanoro
# Processing Record 14 of Set 10 | raahe
# Processing Record 15 of Set 10 | sanandaj
# Processing Record 16 of Set 10 | nuuk
# Processing Record 17 of Set 10 | naugachhia
# Processing Record 18 of Set 10 | panguipulli
# Processing Record 19 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 10 | shchelkun
# Processing Record 21 of Set 10 | nosy varika
# Processing Record 22 of Set 10 | ulyanovo
# City not found. Skipping...
# Processing Record 23 of Set 10 | ampanihy
# Processing Record 24 of Set 10 | chuy
# Processing Record 25 of Set 10 | temecula
# Processing Record 26 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 10 | kuah
# Processing Record 28 of Set 10 | paraiso
# Processing Record 29 of Set 10 | rangapara
# Processing Record 30 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 10 | evensk
# Processing Record 32 of Set 10 | morro agudo
# Processing Record 33 of Set 10 | palaikastron
# Processing Record 34 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 35 of Set 10 | longyearbyen
# Processing Record 36 of Set 10 | athabasca
# Processing Record 37 of Set 10 | puerto leguizamo
# Processing Record 38 of Set 10 | yugorsk
# Processing Record 39 of Set 10 | estepa
# Processing Record 40 of Set 10 | marsh harbour
# Processing Record 41 of Set 10 | novyy urengoy
# Processing Record 42 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 10 | tairua
# Processing Record 44 of Set 10 | oranjestad
# Processing Record 45 of Set 10 | ostrovnoy
# Processing Record 46 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 10 | rosetta
# Processing Record 48 of Set 10 | gambiran
# Processing Record 49 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 10 | nizhniy odes
# Processing Record 1 of Set 11 | zelenogorskiy
# Processing Record 2 of Set 11 | maniitsoq
# Processing Record 3 of Set 11 | svarstad
# Processing Record 4 of Set 11 | rindal
# Processing Record 5 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 6 of Set 11 | aykhal
# Processing Record 7 of Set 11 | ewa beach
# Processing Record 8 of Set 11 | oum hadjer
# Processing Record 9 of Set 11 | keningau
# Processing Record 10 of Set 11 | anchorage
# Processing Record 11 of Set 11 | belle fourche
# Processing Record 12 of Set 11 | hay river
# Processing Record 13 of Set 11 | shenjiamen
# Processing Record 14 of Set 11 | san andres
# Processing Record 15 of Set 11 | yuancheng
# Processing Record 16 of Set 11 | enid
# Processing Record 17 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 11 | saint-paul
# Processing Record 20 of Set 11 | aklavik
# Processing Record 21 of Set 11 | dhone
# Processing Record 22 of Set 11 | aranos
# Processing Record 23 of Set 11 | roebourne
# Processing Record 24 of Set 11 | urusha
# Processing Record 25 of Set 11 | sindor
# Processing Record 26 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 11 | sur
# Processing Record 28 of Set 11 | severomuysk
# Processing Record 29 of Set 11 | bordighera
# Processing Record 30 of Set 11 | olafsvik
# Processing Record 31 of Set 11 | pittsburg
# Processing Record 32 of Set 11 | oriximina
# Processing Record 33 of Set 11 | mwinilunga
# Processing Record 34 of Set 11 | ambon
# Processing Record 35 of Set 11 | bowen
# Processing Record 36 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 11 | belyy yar
# Processing Record 38 of Set 11 | otse
# Processing Record 39 of Set 11 | outjo
# Processing Record 40 of Set 11 | quelimane
# Processing Record 41 of Set 11 | camargo
# Processing Record 42 of Set 11 | bhinga
# Processing Record 43 of Set 11 | maxixe
# Processing Record 44 of Set 11 | formosa do rio preto
# Processing Record 45 of Set 11 | esperance
# Processing Record 46 of Set 11 | rochegda
# Processing Record 47 of Set 11 | valparaiso
# Processing Record 48 of Set 11 | tupik
# Processing Record 49 of Set 11 | mount gambier
# Processing Record 50 of Set 11 | zwedru
# Processing Record 1 of Set 12 | perama
# Processing Record 2 of Set 12 | singleton
# Processing Record 3 of Set 12 | sangar
# Processing Record 4 of Set 12 | adre
# Processing Record 5 of Set 12 | la ronge
# Processing Record 6 of Set 12 | faya
# Processing Record 7 of Set 12 | antofagasta
# Processing Record 8 of Set 12 | upata
# Processing Record 9 of Set 12 | karratha
# Processing Record 10 of Set 12 | banda aceh
# Processing Record 11 of Set 12 | pilani
# Processing Record 12 of Set 12 | ridgecrest
# Processing Record 13 of Set 12 | columbus
# Processing Record 14 of Set 12 | lovozero
# Processing Record 15 of Set 12 | vestmannaeyjar
# Processing Record 16 of Set 12 | basco
# Processing Record 17 of Set 12 | catamarca
# Processing Record 18 of Set 12 | corinto
# Processing Record 19 of Set 12 | mogzon
# Processing Record 20 of Set 12 | koslan
# Processing Record 21 of Set 12 | itaituba
# Processing Record 22 of Set 12 | mayahi
# Processing Record 23 of Set 12 | salinopolis
# Processing Record 24 of Set 12 | krasnoselkup
# Processing Record 25 of Set 12 | sechura
# Processing Record 26 of Set 12 | verkhnevilyuysk
# Processing Record 27 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 12 | porto santo
# Processing Record 29 of Set 12 | pelym
# Processing Record 30 of Set 12 | moree
# Processing Record 31 of Set 12 | bathsheba
# Processing Record 32 of Set 12 | big spring
# Processing Record 33 of Set 12 | san cristobal
# Processing Record 34 of Set 12 | pringsewu
# Processing Record 35 of Set 12 | juazeiro
# Processing Record 36 of Set 12 | thibodaux
# Processing Record 37 of Set 12 | angoche
# Processing Record 38 of Set 12 | virginia beach
# Processing Record 39 of Set 12 | mossendjo
# Processing Record 40 of Set 12 | cayenne
# Processing Record 41 of Set 12 | kahului
# Processing Record 42 of Set 12 | warrington
# Processing Record 43 of Set 12 | ode
# Processing Record 44 of Set 12 | oxbow
# Processing Record 45 of Set 12 | jalu
# Processing Record 46 of Set 12 | motala
# Processing Record 47 of Set 12 | sola
# Processing Record 48 of Set 12 | maningrida
# Processing Record 49 of Set 12 | long xuyen
# Processing Record 50 of Set 12 | sokolo
# Processing Record 1 of Set 13 | araouane
# Processing Record 2 of Set 13 | ust-nera
# Processing Record 3 of Set 13 | ulladulla
# Processing Record 4 of Set 13 | deputatskiy
# Processing Record 5 of Set 13 | los llanos de aridane
# Processing Record 6 of Set 13 | kuito
# Processing Record 7 of Set 13 | slawno
# Processing Record 8 of Set 13 | havoysund
# Processing Record 9 of Set 13 | kanuma
# Processing Record 10 of Set 13 | vanavara
# Processing Record 11 of Set 13 | irece
# Processing Record 12 of Set 13 | berlevag
# Processing Record 13 of Set 13 | kichera
# Processing Record 14 of Set 13 | laguna
# Processing Record 15 of Set 13 | vila velha
# Processing Record 16 of Set 13 | mana
# Processing Record 17 of Set 13 | beder
# Processing Record 18 of Set 13 | polyarnyy
# Processing Record 19 of Set 13 | burkhala
# City not found. Skipping...
# Processing Record 20 of Set 13 | byron bay
# Processing Record 21 of Set 13 | sri aman
# Processing Record 22 of Set 13 | colares
# Processing Record 23 of Set 13 | santona
# Processing Record 24 of Set 13 | japura
# Processing Record 25 of Set 13 | manica
# Processing Record 26 of Set 13 | dzhebariki-khaya
# Processing Record 27 of Set 13 | kamina
# Processing Record 28 of Set 13 | padang
# Processing Record 29 of Set 13 | da nang
# Processing Record 30 of Set 13 | qui nhon
# Processing Record 31 of Set 13 | lauenburg
# Processing Record 32 of Set 13 | jasper
# Processing Record 33 of Set 13 | havelock
# Processing Record 34 of Set 13 | tuckahoe
# Processing Record 35 of Set 13 | abu dhabi
# Processing Record 36 of Set 13 | jiazi
# Processing Record 37 of Set 13 | shimoda
# Processing Record 38 of Set 13 | goderich
# Processing Record 39 of Set 13 | beyneu
# Processing Record 40 of Set 13 | chernyshevskiy
# Processing Record 41 of Set 13 | smithers
# Processing Record 42 of Set 13 | las vegas
# Processing Record 43 of Set 13 | sayyan
# Processing Record 44 of Set 13 | divnomorskoye
# Processing Record 45 of Set 13 | prijepolje
# Processing Record 46 of Set 13 | mahenge
# Processing Record 47 of Set 13 | koumac
# Processing Record 48 of Set 13 | esparta
# Processing Record 49 of Set 13 | muros
# Processing Record 50 of Set 13 | olden
# Processing Record 1 of Set 14 | chitral
# Processing Record 2 of Set 14 | navahrudak
# Processing Record 3 of Set 14 | katherine
# Processing Record 4 of Set 14 | kula
# Processing Record 5 of Set 14 | sambava
# Processing Record 6 of Set 14 | acapulco
# Processing Record 7 of Set 14 | tessalit
# Processing Record 8 of Set 14 | kalmar
# Processing Record 9 of Set 14 | tarko-sale
# Processing Record 10 of Set 14 | villarrica
# Processing Record 11 of Set 14 | terney
# Processing Record 12 of Set 14 | north bend
# Processing Record 13 of Set 14 | ak-dovurak
# Processing Record 14 of Set 14 | giyani
# Processing Record 15 of Set 14 | morehead
# Processing Record 16 of Set 14 | rockingham
# Processing Record 17 of Set 14 | charters towers
# Processing Record 18 of Set 14 | alofi
# Processing Record 19 of Set 14 | lata
# Processing Record 20 of Set 14 | devecser
# Processing Record 21 of Set 14 | at-bashi
# Processing Record 22 of Set 14 | olga
# Processing Record 23 of Set 14 | minab
# Processing Record 24 of Set 14 | chapais
# Processing Record 25 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 14 | mogochin
# City not found. Skipping...
# Processing Record 27 of Set 14 | san jeronimo
# Processing Record 28 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 29 of Set 14 | cap malheureux
# Processing Record 30 of Set 14 | neustrelitz
# Processing Record 31 of Set 14 | tyukhtet
# Processing Record 32 of Set 14 | westport
# Processing Record 33 of Set 14 | muzambinho
# Processing Record 34 of Set 14 | mangrol
# Processing Record 35 of Set 14 | erenhot
# Processing Record 36 of Set 14 | sherlovaya gora
# Processing Record 37 of Set 14 | port-cartier
# Processing Record 38 of Set 14 | kalispell
# Processing Record 39 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 14 | skuodas
# Processing Record 41 of Set 14 | asfi
# Processing Record 42 of Set 14 | cuamba
# Processing Record 43 of Set 14 | grants pass
# Processing Record 44 of Set 14 | viransehir
# Processing Record 45 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 14 | dolores
# Processing Record 47 of Set 14 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 48 of Set 14 | kandrian
# Processing Record 49 of Set 14 | portadown
# Processing Record 50 of Set 14 | kyrnasivka
# Processing Record 1 of Set 15 | dakar
# Processing Record 2 of Set 15 | krasnoshchekovo
# Processing Record 3 of Set 15 | kirensk
# Processing Record 4 of Set 15 | konigs wusterhausen
# Processing Record 5 of Set 15 | basoko
# Processing Record 6 of Set 15 | haines junction
# Processing Record 7 of Set 15 | pitsunda
# Processing Record 8 of Set 15 | inongo
# Processing Record 9 of Set 15 | claveria
# Processing Record 10 of Set 15 | lumut
# Processing Record 11 of Set 15 | bubaque
# Processing Record 12 of Set 15 | general delgado
# Processing Record 13 of Set 15 | bilma
# Processing Record 14 of Set 15 | christchurch
# Processing Record 15 of Set 15 | mwanza
# Processing Record 16 of Set 15 | tongchuan
# Processing Record 17 of Set 15 | bouillante
# Processing Record 18 of Set 15 | fantanele
# Processing Record 19 of Set 15 | la romana
# Processing Record 20 of Set 15 | bambanglipuro
# Processing Record 21 of Set 15 | fortuna
# Processing Record 22 of Set 15 | baraboo
# Processing Record 23 of Set 15 | poronaysk
# Processing Record 24 of Set 15 | warrnambool
# Processing Record 25 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 26 of Set 15 | sandwick
# Processing Record 27 of Set 15 | yarkovo
# Processing Record 28 of Set 15 | adrar
# Processing Record 29 of Set 15 | ierapetra
# Processing Record 30 of Set 15 | praia da vitoria
# Processing Record 31 of Set 15 | yining
# Processing Record 32 of Set 15 | sortavala
# Processing Record 33 of Set 15 | gazanjyk
# Processing Record 34 of Set 15 | macapa
# Processing Record 35 of Set 15 | gamba
# Processing Record 36 of Set 15 | port hardy
# Processing Record 37 of Set 15 | caiaponia
# Processing Record 38 of Set 15 | paamiut
# Processing Record 39 of Set 15 | iskilip
# Processing Record 40 of Set 15 | skjervoy
# Processing Record 41 of Set 15 | tocache
# Processing Record 42 of Set 15 | port hueneme
# Processing Record 43 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 15 | agirish
# Processing Record 45 of Set 15 | castro verde
# Processing Record 46 of Set 15 | santa fe
# Processing Record 47 of Set 15 | praia
# Processing Record 48 of Set 15 | guerrero negro
# Processing Record 49 of Set 15 | ashta
# Processing Record 50 of Set 15 | villablino
# Processing Record 1 of Set 16 | santa rosa
# Processing Record 2 of Set 16 | plettenberg bay
# Processing Record 3 of Set 16 | eten
# Processing Record 4 of Set 16 | matara
# Processing Record 5 of Set 16 | rupert
# Processing Record 6 of Set 16 | erzin
# Processing Record 7 of Set 16 | dickinson
# Processing Record 8 of Set 16 | aktau
# Processing Record 9 of Set 16 | karlskrona
# Processing Record 10 of Set 16 | keetmanshoop
# Processing Record 11 of Set 16 | avera
# Processing Record 12 of Set 16 | luba
# Processing Record 13 of Set 16 | mount isa
# Processing Record 14 of Set 16 | vao
# Processing Record 15 of Set 16 | taldan
# Processing Record 16 of Set 16 | magnolia
# Processing Record 17 of Set 16 | nishihara
# Processing Record 18 of Set 16 | mnogovershinnyy
# Processing Record 19 of Set 16 | gat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 714

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kamenka  51.3223   42.7678     47.08        49           0
# 1     Tilichiki  60.4667  166.1000     26.67        77          73
# 2          Ijui -28.3878  -53.9147     78.82        74          95
# 3  Saint George  37.1041 -113.5841     61.27        52           1
# 4       Mataura -46.1927  168.8643     54.48        87         100
#
#    Wind Speed Country                 Date Current_Description
# 0        5.41      RU  2021-10-10 16:18:47           clear sky
# 1        3.87      RU  2021-10-10 16:18:47       broken clouds
# 2       10.87      BR  2021-10-10 16:18:48     overcast clouds
# 3        1.99      US  2021-10-10 16:15:46           clear sky
# 4        2.71      NZ  2021-10-10 16:28:42       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
